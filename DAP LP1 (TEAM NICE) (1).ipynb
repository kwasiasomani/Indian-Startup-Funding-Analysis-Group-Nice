# %% [markdown]
# # TITLE
#
# # Indian Companies Initial Startup Capital Analysis

# %% [markdown]
# # PROJECT DESCRIPTION
#
#
# # Team niece has been tasked to set out to understand the problem, the indian start up terrain and how best a new business will attract rom investors and propose working course of action.

# %% [markdown]
# # HYPOTHESIS

# %% [markdown]
# # Null Hypothesis, HO
# # There are no exact key factors that correlate with the exact amount of funding contributed by the investors.
#
# # AlternativeHypothesis, H1
# # There are exact key factors that correlate with the exact amount of funding contributed by investors.

# %% [markdown]
# # QUESTIONS

# %% [markdown]
# # Which year has the most funding?
# # Which industry has the most funding?
# # Which industry is fastest growing in funding?
# # Which area has the most funding in India?
# # What is the average funding per year?

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
#loading our data
sheet1=pd.read_csv("startup_funding2018.csv")
sheet2=pd.read_csv("startup_funding2019.csv")
sheet3=pd.read_csv("startup_funding2020.csv")
sheet4=pd.read_csv("startup_funding2021.csv")

# %%
#checking the shape of each file
print(sheet1.shape,sheet2.shape,sheet3.shape,sheet4.shape)
# Out:
# (526, 6) (89, 9) (1055, 10) (1209, 9)

# %%
sheet1.head(2)
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
#
#   Round/Series       Amount                     Location  \
# 0         Seed       250000  Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000   Mumbai, Maharashtra, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...

# %%
sheet2.head(2)
# Out:
#     Company/Brand  Founded HeadQuarter     Sector  \
# 0  Bombay Shaving      NaN         NaN  Ecommerce
# 1       Ruangguru   2014.0      Mumbai     Edtech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
#
#                                 Founders              Investor     Amount($)  \
# 0                     Shantanu Deshpande  Sixth Sense Ventures    $6,300,000
# 1  Adamas Belva Syah Devara, Iman Usman.      General Atlantic  $150,000,000
#
#       Stage
# 0       NaN
# 1  Series C

# %%
sheet3.head(2)
# Out:
#   Company/Brand Founded HeadQuarter    Sector  \
# 0    Aqgromalin    2019     Chennai  AgriTech
# 1      Krayonnz    2019   Bangalore    EdTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
#
#                            Founders         Investor Amount($)     Stage  \
# 0   Prasanna Manogaran, Bharani C L  Angel investors  $200,000       NaN
# 1  Saurabh Dixit, Gurudutt Upadhyay  GSF Accelerator  $100,000  Pre-seed
#
#   Unnamed: 9
# 0        NaN
# 1        NaN

# %%
sheet4.head(2)
# Out:
#     Company/Brand  Founded HeadQuarter      Sector  \
# 0  Unbox Robotics   2019.0   Bangalore  AI startup
# 1          upGrad   2015.0      Mumbai      EdTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
#
#                                    Investor     Amount($)         Stage
# 0               BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1  Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN

# %%
#changing column names
sheet1.rename(columns = {'Company Name':'Company/Brand', 'Industry':'Sector',
                              'Round/Series':'Stage', 'Amount':'Amount($)',
                        'Location':'HeadQuarter'}, inplace = True)

# %%
#delete unnecessary columns
sheet1.drop(columns=['About Company'], axis=1, inplace = True)
sheet2.drop(columns=['What it does', 'Investor', 'Founders'], axis=1, inplace = True)
sheet3.drop(columns=['What it does', 'Investor', 'Founders', 'Unnamed: 9'], axis=1, inplace = True)
sheet4.drop(columns=['What it does', 'Investor', 'Founders'], axis=1, inplace = True)

# %%
print(sheet1.shape,sheet2.shape,sheet3.shape,sheet4.shape)
# Out:
# (526, 5) (89, 6) (1055, 6) (1209, 6)

# %%
sheet1.head(120)
# Out:
#                                Company/Brand  \
# 0                            TheCollegeFever
# 1                            Happy Cow Dairy
# 2                                 MyLoanCare
# 3                                PayMe India
# 4                                   Eunimart
# ..                                       ...
# 115  Satin Creditcare Network Limited (SCNL)
# 116                  APAC Financial Services
# 117                                   Moglix
# 118                     SEDEMAC Mechatronics
# 119                              MadGuy Labs
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 115   Banking, Finance, Financial Services, Non Profit
# 116                        Finance, Financial Services
# 117                            B2B, E-Commerce, Mobile
# 118     Automotive, Electric Vehicle, Renewable Energy
# 119                                         E-Learning
#
#                         Stage       Amount($)  \
# 0                        Seed          250000
# 1                        Seed     ₹40,000,000
# 2                    Series A     ₹65,000,000
# 3                       Angel         2000000
# 4                        Seed               —
# ..                        ...             ...
# 115             Post-IPO Debt     $30,000,000
# 116            Private Equity  ₹2,500,000,000
# 117                  Series C     $23,000,000
# 118  Venture - Series Unknown               —
# 119  Venture - Series Unknown        $150,000
#
#                           HeadQuarter
# 0         Bangalore, Karnataka, India
# 1          Mumbai, Maharashtra, India
# 2             Gurgaon, Haryana, India
# 3         Noida, Uttar Pradesh, India
# 4    Hyderabad, Andhra Pradesh, India
# ..                                ...
# 115           New Delhi, Delhi, India
# 116        Mumbai, Maharashtra, India
# 117       Noida, Uttar Pradesh, India
# 118        Mumbai, Maharashtra, India
# 119  Hyderabad, Andhra Pradesh, India
#
# [120 rows x 5 columns]

# %%
sheet2.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector     Amount($)  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce    $6,300,000
# 1       Ruangguru   2014.0      Mumbai           Edtech  $150,000,000
# 2        Eduisfun      NaN      Mumbai           Edtech   $28,000,000
# 3        HomeLane   2014.0     Chennai  Interior design   $30,000,000
# 4        Nu Genes   2004.0   Telangana         AgriTech    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
sheet3.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector    Amount($)     Stage
# 0    Aqgromalin    2019     Chennai            AgriTech     $200,000       NaN
# 1      Krayonnz    2019   Bangalore              EdTech     $100,000  Pre-seed
# 2  PadCare Labs    2018        Pune  Hygiene management  Undisclosed  Pre-seed
# 3         NCOME    2020   New Delhi              Escrow     $400,000       NaN
# 4    Gramophone    2016      Indore            AgriTech     $340,000       NaN

# %%
sheet4.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector     Amount($)  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup    $1,200,000
# 1          upGrad   2015.0      Mumbai          EdTech  $120,000,000
# 2     Lead School   2012.0      Mumbai          EdTech   $30,000,000
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce   $51,000,000
# 4        FypMoney   2021.0    Gurugram         FinTech    $2,000,000
#
#           Stage
# 0  Pre-series A
# 1           NaN
# 2      Series D
# 3      Series C
# 4          Seed

# %%
#calculating the amount column for 2018
sheet1['Amount($)'] = sheet1['Amount($)']. apply(lambda x: str(x).replace('—','NaN'))
#sheet1['Amount($)'] = sheet1['Amount($)']. apply(lambda x: str(x).replace('₹',''))
#sheet1['Amount($)'] = sheet1['Amount($)']. apply(lambda x: str(x).replace('$',''))
#sheet1['Amount($)'] = sheet1['Amount($)']. apply(lambda x: str(x).replace(',',''))
